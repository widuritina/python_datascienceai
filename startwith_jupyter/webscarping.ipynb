# %% [markdown]
# # Web Scraping

# %%
pip install requests

# %%
pip install bs4

# %%
import requests
from bs4 import BeautifulSoup

url='https://en.wikipedia.org/wiki/IBM'
response=requests.get(url)
response.text               #response in html
soup=BeautifulSoup(response.text, 'html.parser')
soup
response.text[:500]
soup.find_all('a')
print(response.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>IBM - Wikipedia</title>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os
from PIL import Image
from IPython.display import IFrame

url="https://www.ibm.com/"
response=requests.get(url)
response.status_code
response.request.body
response.request.headers
header=response.headers
header['Date']
header['Content-Type']
response.text

#Image URL
url2='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/IDSNlogo.png'
res=requests.get(url)
res.headers['Content-Type']

path=os.path.join(os.getcwd(),'/Workspaces/Python Workspace/startwith_jupyter/data/image.png')
with open(path,'wb') as i:
    i.write(res.content)

#Image.open(path)
res.content

# %%
pip install --upgrade pip

# %%
pip install os_

# %%
import requests
path='/Workspaces/Python Workspace/startwith_jupyter/data/Exmpl1.txt'
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%205/data/Example1.txt'
resp=requests.get(url)
resp.content            #content of response
with open(path,'wb') as file1:
    file1.write(resp.content)

# %%
url_get='http://httpbin.org/get'
payload={'name':'Joseph','ID':'123'}
resp= requests.get(url_get,params=payload)
resp.url
resp.request.body
resp.json()['args']

url_post='http://httpbin.org/post'
resp=requests.post(url_post,params=payload)
resp.json()['form']
# Out:
# {}

# %% [markdown]
# ## Using BeautifulSoup

# %%
from bs4 import BeautifulSoup
import requests

url='http://www.example.com'
resp=requests.get(url)
parsed=BeautifulSoup(resp.content,'html.parser')
parsed.body
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n  
# ...

# %%
from bs4 import BeautifulSoup
import requests

html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"
parsed_html=BeautifulSoup(html,'html.parser')

parsed_html
print(parsed_html.prettify())        #display HML in nested structure
#soup tags
parsed_html.title
parsed_html.body
tag_object=parsed_html.h3
parent_tag=parsed_html.parent
tag_child=parsed_html.b
parent_tag=tag_child.parent         #same with parsed_html.h3.parent
parent_tag
tag_object.parent
sibling_1=tag_object.next_sibling
sibling_1
sibling_2=sibling_1.next_sibling
sibling_2
#html attributes
tag_child['id']
tag_child.attrs
tag_child.get('id')
tag_string=tag_child.string            #extracting the string of the tag
type(tag_string)                        #navigable string
unicode_string=str(tag_string)
type(unicode_string)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>
# <table><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr></table>

# %%
html_table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"
soup=BeautifulSoup(html_table,'html.parser')
rows=soup.find_all('tr')                 #find all tags in html, return to list
first_row=rows[0]
type(first_row)
first_row.td
for i,row in enumerate(rows):
    cells=row.find_all('td')
    print(f"Row {i}: {cells}")
    for j,cell in enumerate(cells):
        print(f"Cell {j}: {cell}")

soup.find_all(id="flight")
list_input=soup.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
soup.find_all(href=True)
soup.find_all(href=False)
soup.find_all(id='boldest')
str(soup.find_all(string="Florida"))
# Out:
# Row 0: [<td id="flight">Flight No</td>, <td>Launch site</td>, <td>Payload mass</td>]
# Cell 0: <td id="flight">Flight No</td>
# Cell 1: <td>Launch site</td>
# Cell 2: <td>Payload mass</td>
# Row 1: [<td>1</td>, <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>, <td>300 kg</td>]
# Cell 0: <td>1</td>
# Cell 1: <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>
# Cell 2: <td>300 kg</td>
# Row 2: [<td>2</td>, <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>, <td>94 kg</td>]
# Cell 0: <td>2</td>
# Cell 1: <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# Cell 2: <td>94 kg</td>
# Row 3: [<td>3</td>, <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>, <td>80 kg</td>]
# Cell 0: <td>3</td>
# Cell 1: <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>
# Cell 2: <td>80 kg</td>
# "['Florida', 'Florida']"

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"
soup2=BeautifulSoup(two_tables,'html.parser')
soup2.find('table')
soup2.find("table",class_='pizza')

url3="http://www.ibm.com"
resp3=requests.get(url3)
soup3=BeautifulSoup(resp3.content,'html.parser')
soup3.body
list_link=soup3.find_all('a',href=True)
for link in list_link:
    print(f"{link.string}: {link.get('href')}")
list_img=soup3.find_all('img')
for img in list_img:
    print(f"{img.get('alt')}: {img.get('src')}")

url4="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"
resp4=requests.get(url4)
soup4=BeautifulSoup(resp4.content,'html.parser')
tables4=soup4.find_all('table')
rows4=soup4.find_all('tr') 
for row in rows4:
    #print(row.find_all('td'))
    cols=row.find_all('td')
    print(f"{cols[2].string} -> {cols[3].string}")
    #print(row.find_all('style'))
cols
# Out:
# infrastruktur hybrid cloud: https://www.ibm.com/cloud?lnk=intro
# Potret para konsultan IBM: /content/dam/adobe-cms/default-images/home-consultants.component.crop-16by9-xl.ts=1695238692853.jpg/content/adobe-cms/id/id/homepage/_jcr_content/root/table_of_contents/simple_image
# Color Name -> None
# lightsalmon -> #FFA07A
# salmon -> #FA8072
# darksalmon -> #E9967A
# lightcoral -> #F08080
# coral -> #FF7F50
# tomato -> #FF6347
# orangered -> #FF4500
# gold -> #FFD700
# orange -> #FFA500
# darkorange -> #FF8C00
# lightyellow -> #FFFFE0
# lemonchiffon -> #FFFACD
# papayawhip -> #FFEFD5
# moccasin -> #FFE4B5
# peachpuff -> #FFDAB9
# palegoldenrod -> #EEE8AA
# khaki -> #F0E68C
# darkkhaki -> #BDB76B
# yellow -> #FFFF00
# lawngreen -> #7CFC00
# chartreuse -> #7FFF00
# limegreen -> #32CD32
# lime -> #00FF00
# forestgreen -> #228B22
# green -> #008000
# powderblue -> #B0E0E6
# lightblue -> #ADD8E6
# lightskyblue -> #87CEFA
# skyblue -> #87CEEB
# deepskyblue -> #00BFFF
# ...

# %% [markdown]
# ## Scrapy

# %%
pip install scrapy
# Out:
# ...
#      ---------------------------------------- 0.0/44.1 kB ? eta -:--:--
#      ---------------------------------------- 44.1/44.1 kB 2.1 MB/s eta 0:00:00
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached cffi-1.16.0-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#    ---------------------------------------- 0.0/290.1 kB ? eta -:--:--
#    ----------------------------------- ---- 256.0/290.1 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 290.1/290.1 kB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
# ...

# %%
import scrapy
class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = ['http://quotes.toscrape.com/tag/humor/',]
    
    def parse(self,response):
        for quote in response.css('div,quote'):

# %% [markdown]
# ## Using Pandas

# %%
import pandas

#url='https://en.wikipedia.org/wiki/List_of_largest_banks'
url='https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)'
table=pandas.read_html(url) # could be used to scrap tabular information
print(len(table))
print(table)
# Out:
# 7
# [                                                   0
# 0  Largest economies in the world by GDP (nominal...,                                                    0  \
# 0  > $20 trillion $10–20 trillion $5–10 trillion ...
#
#                                                    1  \
# 0  $750 billion – $1 trillion $500–750 billion $2...
#
#                                                    2
# 0  $50–100 billion $25–50 billion $5–25 billion <...  ,     Country/Territory IMF[1][13]            World Bank[14]             \
#     Country/Territory   Forecast       Year       Estimate       Year
# 0               World  109529216       2024      105435540       2023
# 1       United States   28781083       2024       27360935       2023
# 2               China   18532633  [n 1]2024       17794782  [n 3]2023
# 3             Germany    4591100       2024        4456081       2023
# 4               Japan    4110452       2024        4212945       2023
# ...
